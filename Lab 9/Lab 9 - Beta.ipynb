# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
def run(is_training=True, render=False):

    env = gym.make('Acrobot-v1', render_mode='human' if render else None)

    # hyperparameters
    learning_rate_a = 0.1        # alpha aka learning rate
    discount_factor_g = 0.9      # gamma aka discount factor.
    epsilon = 1                  # start episilon at 1 (100% random actions)
    epsilon_decay_rate = 0.0005  # epsilon decay rate
    epsilon_min = 0.05           # minimum epsilon
    divisions = 15               # used to convert continuous state space to discrete space

    # Divide continuous observation space into discrete segments
    th1_cos  = np.linspace(env.observation_space.low[0], env.observation_space.high[0], divisions)
    th1_sin  = np.linspace(env.observation_space.low[1], env.observation_space.high[1], divisions)
    th2_cos  = np.linspace(env.observation_space.low[2], env.observation_space.high[2], divisions)
    th2_sin  = np.linspace(env.observation_space.low[3], env.observation_space.high[3], divisions)
    th1_w    = np.linspace(env.observation_space.low[4], env.observation_space.high[4], divisions)
    th2_w    = np.linspace(env.observation_space.low[5], env.observation_space.high[5], divisions)

    if(is_training):
        # initialize q table to 15x15x15x15x15x15x3 array. 16 = division of 15 plus 1 extra slice
        q = np.zeros((len(th1_cos)+1, len(th1_sin)+1,
                      len(th2_cos)+1, len(th2_sin)+1,
                      len(th1_w)+1, len(th2_w)+1,
                      env.action_space.n))
    else:
        f = open('acrobot.pkl', 'rb')
        q = pickle.load(f)
        f.close()

    best_reward = -999999        # track best reward
    rewards_per_episode = []     # list to store rewards for each episode
    i = 0                        # episode counter

    while(True):

        state = env.reset()[0]      # Starting position

        # Convert continuous state to discrete state
        s_i0  = np.digitize(state[0], th1_cos)
        s_i1  = np.digitize(state[1], th1_sin)
        s_i2  = np.digitize(state[2], th2_cos)
        s_i3  = np.digitize(state[3], th2_sin)
        s_i4  = np.digitize(state[4], th1_w)
        s_i5  = np.digitize(state[5], th2_w)

        terminated = False          # True when reached goal
        rewards=0                   # rewards collected per episode

        # Episode
        while(not terminated):

            if is_training and np.random.rand() < epsilon:
                # Choose random action
                action = env.action_space.sample()
            else:
                # Choose best action
                action = np.argmax(q[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, :])

            # Take action
            new_state,reward,terminated,_,_ = env.step(action)

            # Convert continuous state to discrete space
            ns_i0  = np.digitize(new_state[0], th1_cos)
            ns_i1  = np.digitize(new_state[1], th1_sin)
            ns_i2  = np.digitize(new_state[2], th2_cos)
            ns_i3  = np.digitize(new_state[3], th2_sin)
            ns_i4  = np.digitize(new_state[4], th1_w)
            ns_i5  = np.digitize(new_state[5], th2_w)

            # Update Q table
            if is_training:
                q[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, action] += \
                    learning_rate_a * (
                        reward +
                        discount_factor_g * np.max(q[ns_i0, ns_i1, ns_i2, ns_i3, ns_i4, ns_i5,:]) -
                        q[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, action]
                    )
        
            # Set state to new state
            state = new_state
            s_i0 = ns_i0
            s_i1 = ns_i1
            s_i2 = ns_i2
            s_i3 = ns_i3
            s_i4 = ns_i4
            s_i5 = ns_i5

            # Collect rewards
            rewards+=reward

        if rewards>best_reward:
            best_reward = rewards

            # Save Q table to file on new best reward
            if is_training:
                f = open('acrobot.pkl','wb')
                pickle.dump(q, f)
                f.close()

        # Store rewards per episode
        rewards_per_episode.append(rewards)

        # Print stats
        if is_training and i!=0 and i%100==0:
            # Calculate mean reward over the last 100 episodes
            mean_reward = np.mean(rewards_per_episode[len(rewards_per_episode)-100:])
            print(f'Episode: {i}, Epsilon: {epsilon:0.2f}, Best Reward: {best_reward:0.1f}, Mean Rewards {mean_reward:0.1f}')

            # Graph mean rewards
            mean_rewards = []
            for t in range(i):
                # Calculate mean reward over the t-100 episodes
                mean_rewards.append(np.mean(rewards_per_episode[max(0, t-100):(t+1)]))
            plt.plot(mean_rewards)
            plt.savefig(f'acrobot.png')

        elif not is_training:
            print(f'Episode: {i} Rewards: {rewards:0.1f}')

        # Stop, if solved
        if best_reward>env.spec.reward_threshold:
            break

        # Decay epsilon
        epsilon = max(epsilon - epsilon_decay_rate, epsilon_min)

        # Increment episode counter
        i+=1

    env.close()

# %%
if __name__ == '__main__':
    run(is_training=True, render=False)

    # run(is_training=False, render=True)
# Out:
# Episode: 100, Epsilon: 0.95, Best Reward: -452.0, Mean Rewards -2087.8
# Episode: 200, Epsilon: 0.90, Best Reward: -424.0, Mean Rewards -1778.0
# Episode: 300, Epsilon: 0.85, Best Reward: -424.0, Mean Rewards -1551.4
# Episode: 400, Epsilon: 0.80, Best Reward: -424.0, Mean Rewards -1177.6
# Episode: 500, Epsilon: 0.75, Best Reward: -302.0, Mean Rewards -983.5
# Episode: 600, Epsilon: 0.70, Best Reward: -254.0, Mean Rewards -851.4
# Episode: 700, Epsilon: 0.65, Best Reward: -222.0, Mean Rewards -829.6
# Episode: 800, Epsilon: 0.60, Best Reward: -222.0, Mean Rewards -680.6
# Episode: 900, Epsilon: 0.55, Best Reward: -222.0, Mean Rewards -645.4
# Episode: 1000, Epsilon: 0.50, Best Reward: -222.0, Mean Rewards -618.6
# Episode: 1100, Epsilon: 0.45, Best Reward: -222.0, Mean Rewards -598.5
# Episode: 1200, Epsilon: 0.40, Best Reward: -170.0, Mean Rewards -519.0
# Episode: 1300, Epsilon: 0.35, Best Reward: -170.0, Mean Rewards -528.6
# Episode: 1400, Epsilon: 0.30, Best Reward: -164.0, Mean Rewards -529.8
# Episode: 1500, Epsilon: 0.25, Best Reward: -164.0, Mean Rewards -469.4
# Episode: 1600, Epsilon: 0.20, Best Reward: -148.0, Mean Rewards -500.9
# Episode: 1700, Epsilon: 0.15, Best Reward: -148.0, Mean Rewards -485.0
# Episode: 1800, Epsilon: 0.10, Best Reward: -148.0, Mean Rewards -430.5
# Episode: 1900, Epsilon: 0.05, Best Reward: -148.0, Mean Rewards -381.3
# Episode: 2000, Epsilon: 0.05, Best Reward: -138.0, Mean Rewards -411.7
# Episode: 2100, Epsilon: 0.05, Best Reward: -138.0, Mean Rewards -415.4
# Episode: 2200, Epsilon: 0.05, Best Reward: -138.0, Mean Rewards -472.3
# Episode: 2300, Epsilon: 0.05, Best Reward: -138.0, Mean Rewards -433.4
# Episode: 2400, Epsilon: 0.05, Best Reward: -138.0, Mean Rewards -452.3
# Episode: 2500, Epsilon: 0.05, Best Reward: -138.0, Mean Rewards -441.0
# Episode: 2600, Epsilon: 0.05, Best Reward: -138.0, Mean Rewards -406.9
# Episode: 2700, Epsilon: 0.05, Best Reward: -138.0, Mean Rewards -425.4
Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -286.3
# Episode: 11500, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -329.3
# Episode: 11600, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -264.7
# Episode: 11700, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -285.4
# Episode: 11800, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -273.9
# Episode: 11900, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -307.3
# Episode: 12000, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -269.7
# Episode: 12100, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -292.1
# Episode: 12200, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -304.3
# Episode: 12300, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -285.1
# Episode: 12400, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -299.9
# Episode: 12500, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -294.2
# Episode: 12600, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -294.4
# Episode: 12700, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -304.9
# Episode: 12800, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -286.7
# Episode: 12900, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -297.6
# Episode: 13000, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -300.3
# Episode: 13100, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -283.4
# Episode: 13200, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -279.1
# Episode: 13300, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -257.9
# Episode: 13400, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -302.1
# Episode: 13500, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -255.7
# Episode: 13600, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -302.8
# Episode: 13700, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -327.9
# Episode: 13800, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -333.5
# Episode: 13900, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -346.2
# Episode: 14000, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -356.0
# Episode: 14100, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -344.1
# Episode: 14200, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -363.8
# Episode: 14300, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -373.7
# Episode: 14400, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -306.6
# Episode: 14500, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -315.6
# Episode: 14600, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -309.4
# Episode: 14700, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -296.3
# Episode: 14800, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -302.0
# Episode: 14900, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -294.6
# Episode: 15000, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -281.5
# Episode: 15100, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -301.7
# Episode: 15200, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -288.5
# Episode: 15300, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -338.2
# Episode: 15400, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -266.4
# Episode: 15500, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -257.3
# Episode: 15600, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -260.0
# Episode: 15700, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -272.1
# Episode: 15800, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -253.8
# Episode: 15900, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -263.4
# Episode: 16000, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -251.0
# Episode: 16100, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -254.5
# Episode: 16200, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -236.2
# Episode: 16300, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -248.5
# Episode: 16400, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -247.2
# Episode: 16500, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -255.8
# Episode: 16600, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -254.2
# Episode: 16700, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -261.6
# Episode: 16800, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -273.4
# Episode: 16900, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -269.9
# Episode: 17000, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -274.9
# Episode: 17100, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -279.6
# Episode: 17200, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -273.9
# Episode: 17300, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -280.1
# Episode: 17400, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -292.0
# Episode: 17500, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -270.4
# Episode: 17600, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -281.1
# Episode: 17700, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -307.0
# Episode: 17800, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -304.9
# Episode: 17900, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -309.2
# Episode: 18000, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -313.7
# Episode: 18100, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -280.3
# Episode: 18200, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -264.3
# Episode: 18300, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -283.3
# Episode: 18400, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -268.8
# Episode: 18500, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -309.7
# Episode: 18600, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -286.0
# Episode: 18700, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -270.6
# Episode: 18800, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -253.5
# Episode: 18900, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -258.3
# Episode: 19000, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -254.5
# Episode: 19100, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -275.3
# Episode: 19200, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -265.4
# Episode: 19300, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -283.0
# Episode: 19400, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -265.4
# Episode: 19500, Epsilon: 0.05, Best Reward: -104.0, Mean Rewards -274.1

# %%
def run_double_q(is_training=True, render=False):

    env = gym.make('Acrobot-v1', render_mode='human' if render else None)

    # hyperparameters
    learning_rate_a = 0.1        # alpha aka learning rate
    discount_factor_g = 0.9      # gamma aka discount factor.
    epsilon = 1                  # start episilon at 1 (100% random actions)
    epsilon_decay_rate = 0.0005  # epsilon decay rate
    epsilon_min = 0.05           # minimum epsilon
    divisions = 15               # used to convert continuous state space to discrete space

    # Divide continuous observation space into discrete segments
    th1_cos  = np.linspace(env.observation_space.low[0], env.observation_space.high[0], divisions)
    th1_sin  = np.linspace(env.observation_space.low[1], env.observation_space.high[1], divisions)
    th2_cos  = np.linspace(env.observation_space.low[2], env.observation_space.high[2], divisions)
    th2_sin  = np.linspace(env.observation_space.low[3], env.observation_space.high[3], divisions)
    th1_w    = np.linspace(env.observation_space.low[4], env.observation_space.high[4], divisions)
    th2_w    = np.linspace(env.observation_space.low[5], env.observation_space.high[5], divisions)

    if(is_training):
        # initialize q table to 15x15x15x15x15x15x3 array. 16 = division of 15 plus 1 extra slice
        q_1 = np.zeros((len(th1_cos)+1, len(th1_sin)+1,
                      len(th2_cos)+1, len(th2_sin)+1,
                      len(th1_w)+1, len(th2_w)+1,
                      env.action_space.n))
        
        q_2 = np.zeros((len(th1_cos)+1, len(th1_sin)+1,
                      len(th2_cos)+1, len(th2_sin)+1,
                      len(th1_w)+1, len(th2_w)+1,
                      env.action_space.n))
    else:
        f = open('acrobot_q1.pkl', 'rb')
        q_1 = pickle.load(f)
        f.close()
        f = open('acrobot_q2.pkl', 'rb')
        q_2 = pickle.load(f)
        f.close()

    best_reward = -999999        # track best reward
    rewards_per_episode = []     # list to store rewards for each episode
    i = 0                        # episode counter

    while(True):

        state = env.reset()[0]      # Starting position

        # Convert continuous state to discrete state
        s_i0  = np.digitize(state[0], th1_cos)
        s_i1  = np.digitize(state[1], th1_sin)
        s_i2  = np.digitize(state[2], th2_cos)
        s_i3  = np.digitize(state[3], th2_sin)
        s_i4  = np.digitize(state[4], th1_w)
        s_i5  = np.digitize(state[5], th2_w)

        terminated = False          # True when reached goal
        rewards=0                   # rewards collected per episode

        # Episode
        while(not terminated):

            if is_training and np.random.rand() < epsilon:
                # Choose random action
                action = env.action_space.sample()
            else:
                # Choose best action
                action = np.argmax(q_1[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, :] +
                                   q_2[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, :])

            # Take action
            new_state,reward,terminated,_,_ = env.step(action)

            # Convert continuous state to discrete space
            ns_i0  = np.digitize(new_state[0], th1_cos)
            ns_i1  = np.digitize(new_state[1], th1_sin)
            ns_i2  = np.digitize(new_state[2], th2_cos)
            ns_i3  = np.digitize(new_state[3], th2_sin)
            ns_i4  = np.digitize(new_state[4], th1_w)
            ns_i5  = np.digitize(new_state[5], th2_w)

            # Update Q table
            if is_training:
                if np.random.rand() < 0.5:
                    q_1[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, action] += \
                        learning_rate_a * (
                            reward +
                            discount_factor_g * np.max(q_2[ns_i0, ns_i1, ns_i2, ns_i3, ns_i4, ns_i5,:]) -
                            q_1[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, action]
                        )
                else:
                    q_2[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, action] += \
                        learning_rate_a * (
                            reward +
                            discount_factor_g * np.max(q_1[ns_i0, ns_i1, ns_i2, ns_i3, ns_i4, ns_i5,:]) -
                            q_2[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, action]
                        )
                    
        
            # Set state to new state
            state = new_state
            s_i0 = ns_i0
            s_i1 = ns_i1
            s_i2 = ns_i2
            s_i3 = ns_i3
            s_i4 = ns_i4
            s_i5 = ns_i5

            # Collect rewards
            rewards+=reward

        if rewards>best_reward:
            best_reward = rewards

            # Save Q table to file on new best reward
            if is_training:
                f = open('acrobot_q1.pkl','wb')
                pickle.dump(q_1, f)
                f.close()

                f = open('acrobot_q2.pkl','wb')
                pickle.dump(q_2, f)
                f.close()

        # Store rewards per episode
        rewards_per_episode.append(rewards)

        # Print stats
        if is_training and i!=0 and i%100==0:
            # Calculate mean reward over the last 100 episodes
            mean_reward = np.mean(rewards_per_episode[len(rewards_per_episode)-100:])
            print(f'Episode: {i}, Epsilon: {epsilon:0.2f}, Best Reward: {best_reward:0.1f}, Mean Rewards {mean_reward:0.1f}')

            # Graph mean rewards
            mean_rewards = []
            for t in range(i):
                # Calculate mean reward over the t-100 episodes
                mean_rewards.append(np.mean(rewards_per_episode[max(0, t-100):(t+1)]))
            plt.plot(mean_rewards)
            plt.savefig(f'acrobot.png')

        elif not is_training:
            print(f'Episode: {i} Rewards: {rewards:0.1f}')

        # Stop, if solved
        if best_reward>env.spec.reward_threshold:
            break

        # Decay epsilon
        epsilon = max(epsilon - epsilon_decay_rate, epsilon_min)

        # Increment episode counter
        i+=1

    env.close()

# %%
if __name__ == '__main__':
    run_double_q(is_training=True, render=False)

    # run(is_training=False, render=True)
# Out:
# Episode: 100, Epsilon: 0.95, Best Reward: -344.0, Mean Rewards -2015.6
# Episode: 200, Epsilon: 0.90, Best Reward: -344.0, Mean Rewards -1670.8
# Episode: 300, Epsilon: 0.85, Best Reward: -342.0, Mean Rewards -1471.4
# Episode: 400, Epsilon: 0.80, Best Reward: -329.0, Mean Rewards -1392.6
# Episode: 500, Epsilon: 0.75, Best Reward: -278.0, Mean Rewards -1228.5
# Episode: 600, Epsilon: 0.70, Best Reward: -255.0, Mean Rewards -1127.7
# Episode: 700, Epsilon: 0.65, Best Reward: -255.0, Mean Rewards -947.8
# Episode: 800, Epsilon: 0.60, Best Reward: -255.0, Mean Rewards -870.6
# Episode: 900, Epsilon: 0.55, Best Reward: -231.0, Mean Rewards -791.1
# Episode: 1000, Epsilon: 0.50, Best Reward: -224.0, Mean Rewards -692.1
# Episode: 1100, Epsilon: 0.45, Best Reward: -210.0, Mean Rewards -644.2
# Episode: 1200, Epsilon: 0.40, Best Reward: -210.0, Mean Rewards -658.8
# Episode: 1300, Epsilon: 0.35, Best Reward: -145.0, Mean Rewards -624.5
# Episode: 1400, Epsilon: 0.30, Best Reward: -145.0, Mean Rewards -612.0
# Episode: 1500, Epsilon: 0.25, Best Reward: -145.0, Mean Rewards -545.7
# Episode: 1600, Epsilon: 0.20, Best Reward: -145.0, Mean Rewards -568.2
# Episode: 1700, Epsilon: 0.15, Best Reward: -145.0, Mean Rewards -572.7
# Episode: 1800, Epsilon: 0.10, Best Reward: -145.0, Mean Rewards -524.1
# Episode: 1900, Epsilon: 0.05, Best Reward: -145.0, Mean Rewards -506.4
# Episode: 2000, Epsilon: 0.05, Best Reward: -145.0, Mean Rewards -547.6
# Episode: 2100, Epsilon: 0.05, Best Reward: -145.0, Mean Rewards -568.7
# Episode: 2200, Epsilon: 0.05, Best Reward: -145.0, Mean Rewards -582.2
# Episode: 2300, Epsilon: 0.05, Best Reward: -145.0, Mean Rewards -494.7
# Episode: 2400, Epsilon: 0.05, Best Reward: -145.0, Mean Rewards -533.9
# Episode: 2500, Epsilon: 0.05, Best Reward: -145.0, Mean Rewards -563.2
